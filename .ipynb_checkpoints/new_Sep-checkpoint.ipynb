# %%
import itertools
from copy import deepcopy as copy

# from netgraph import InteactiveGraph # pip install netgraph
from functools import reduce
from itertools import chain, permutations, product
from operator import itemgetter
from time import time

import cvxpy as cp
import matplotlib as mpl
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import scipy
from numpy.linalg import matrix_rank as rank
from scipy.linalg import block_diag, fractional_matrix_power
from scipy.sparse import coo_array, csr_array

from utils.Adversary import Adversary
from utils.Conversions import hamming_dist as dist
from utils.Conversions import (
    mask_maker,
    partial,
    to_adversary_mat,
    to_str,
    to_str_list,
    visualize,
)
from utils.Problems import ED, Problem, exact_k, threshold_k
from utils.Solvers import (
    adv_solver,
    instance_mask,
    ket,
    relative_hadamard_norm_max,
    type_mask,
)

mpl.rcParams["figure.dpi"] = 120
from multiprocessing.pool import ThreadPool as Pool

# %%
def get_instance_delta(x, y):
    n = len(x)
    mat = np.zeros((n, n))
    for i, (a, b) in enumerate(zip(x, y)):
        if a != b:
            mat[i, i] = 1
    return mat

def get_deltas(problem):
    return {(no, yes): np.kron(instance_mask(problem, no, yes), get_instance_delta(no, yes)) for no, yes in product(problem.no_instances, problem.yes_instances)}

def get_delta(prob):
    no_zero_size = prob.no_len * prob.n
    yes_zero_size = prob.yes_len * prob.n
    labels = to_str_list(list(itertools.product((prob.instances), range(n))))
    instance_mats = []
    for no in prob.no_instances:
        instance_mats.append([])
        no_i = prob.instance_to_index[no]
        for yes in prob.yes_instances:
            yes_i = prob.instance_to_index[yes]
            instance_mats[-1].append(get_instance_delta(no, yes))
    instance_mats = np.block(instance_mats)
    mat = np.block(
        [
            [np.zeros((no_zero_size, no_zero_size)), instance_mats],
            [instance_mats.T, np.zeros((yes_zero_size, yes_zero_size))],
        ]
    )
    return mat, labels


def get_Dz(prob, instance):
    instance_mat = np.zeros((prob.len, prob.len))
    i = prob.instance_to_index[instance]
    instance_mat[i, i] = 1
    return np.kron(instance_mat, np.eye(prob.n))


def vec(A):
    m, n = A.shape[0], A.shape[1]
    return A.reshape(m * n, order="F")


def commutation_matrix_sp(A):
    m, n = A.shape[0], A.shape[1]
    row = np.arange(m * n)
    col = row.reshape((m, n), order="F").ravel()
    data = np.ones(m * n, dtype=np.int8)
    K = csr_matrix((data, (row, col)), shape=(m * n, m * n))
    return K


# (i, j) -> (j, i)
def transpose_mat(size):
    trans = np.zeros((size**2, size**2))
    for i in range(size):
        for j in range(size):
            row = size * i + j
            col = size * j + i
            trans[row, col] = 1

    return trans


def partial_transpose_fast(size):
    print("size", size)
    small_size = int(np.sqrt(size))
    assert small_size**2 == size
    print("small size", small_size)
    I = coo_array(np.eye(small_size))
    print(I)
    T = coo_array(transpose_mat(small_size))
    partial_T_vec = scipy.sparse.kron(coo_array(np.eye(size)), T)
    conv = scipy.sparse.kron(I, scipy.sparse.kron(T, I))
    pt = conv @ partial_T_vec @ conv
    print(pt.shape, T.shape)
    return pt
    # for i in range(small)


def partial_transpose(mat, dim1=None, dim2=None, NP=False):
    assert mat.shape[0] == mat.shape[1]
    mat_size = mat.shape[0]
    if dim1 is None:
        size = int(np.sqrt(mat_size))
        dim1 = size
        dim2 = size
    elif dim2 is None:
        dim2 = mat_size // dim1
    print("dima=", dim1, dim2)

    assert dim2 * dim1 == mat_size, (
        "dim1=" + str(dim1) + ", dim2=" + str(dim2) + ", mat_size=" + str(mat_size)
    )

    pt_mat = cp.bmat(
        [
            [
                mat[i * dim2 : (i + 1) * dim2, j * dim2 : (j + 1) * dim2]
                for i in range(dim1)
            ]
            for j in range(dim1)
        ]
    )

    if NP:
        pt_mat = [
            [
                mat[i * dim2 : (i + 1) * dim2, j * dim2 : (j + 1) * dim2]
                for i in range(dim1)
            ]
            for j in range(dim1)
        ]

        print(pt_mat)
        pt_mat = np.block(pt_mat)
    return pt_mat

def symmetry_projection2(size):
    part_size = int(np.sqrt(size))
    
def symmetry_projection(pairs):
    if isinstance(pairs, int):
        part_size = int(np.sqrt(pairs))
        assert part_size**2 == pairs
        pairs = list(product(range(part_size), range(part_size)))
    proj = np.zeros((len(pairs), len(pairs)))
    inv_pairs = inv_map(pairs)
    for pair in pairs:
        pair_i = inv_pairs[pair]
        pair_rev = pair[::-1]
        pair_rev_i = inv_pairs[pair_rev]
        if not (pair == pair_rev and pair[0] != pair[1]):
            proj[pair_i, pair_rev_i] = 1
    return np.eye(len(pairs)) / 2 + proj / 2


def get_swap_mat(pairs):
    if isinstance(pairs, int):
        part_size = int(np.sqrt(pairs))
        assert part_size**2 == pairs
        pairs = list(product(range(part_size), range(part_size)))

    return 2 * symmetry_projection(pairs) - np.eye(len(pairs))


def inv_map(map):
    return {image: preimage for preimage, image in enumerate(map)}


import numpy as np


def commutation_matrix(d):
    """
    Full transpose (commutation) matrix T_d of size d^2 x d^2.
    vec(X^T) = T_d @ vec(X)
    """
    T = np.zeros((d * d, d * d), dtype=int)
    for i in range(d):
        for j in range(d):
            row = i * d + j
            col = j * d + i
            T[row, col] = 1
    return T

# %%
def get_delta_constraint_mats(problem, rank):
    num_pairs = 2 * problem.no_len * problem.yes_len
    deltas = dict()
    delta, labels = get_delta(problem)
    proj = symmetry_projection((problem.len * rank * problem.n)**2)
    for (no, yes), curr_delta in get_deltas(problem).items(): 
        curr_delta = delta / num_pairs - curr_delta
        curr_delta = np.kron(curr_delta, np.eye(rank))
        curr_delta = np.kron(curr_delta, curr_delta)
        deltas[(no, yes)] = curr_delta
        print(np.linalg.norm(proj@curr_delta@proj))
    return deltas


def get_D_constraint_mats(problem, rank):
    D_mats = dict()
    for instance in problem.instances:
        curr_D = get_Dz(problem, instance) - np.eye(problem.len * problem.n) / prob.len
        curr_D = np.kron(curr_D, np.eye(rank))
        curr_D = np.kron(curr_D, curr_D)
        D_mats[instance] = curr_D
    return D_mats

def get_Ds(problem):
    return [get_Dz(problem, instance) for instance in problem.instances]
    
def space_adv_psd(problem, rank):
    num_pairs = 2*problem.no_len * problem.yes_len
    delta, labels = get_delta(problem)
    deltas = get_delta_constraint_mats(problem, rank)
    n = problem.n
    D_mats = get_D_constraint_mats(problem, rank)
    A = cp.Variable((problem.len, problem.len), symmetric=True)
    b = cp.Variable(problem.len)
    lam = cp.Variable()
    delta_to_sum = [
        A[problem.instance_to_index[no], problem.instance_to_index[yes]]
        * deltas[no, yes]
        for no, yes in product(problem.no_instances, problem.yes_instances)
    ]
    for pair, d in deltas.items():
        visualize(d, title=str(pair))
    
    delta_sum = cp.sum(delta_to_sum, axis=0)
    delta_sum = delta_sum + delta_sum.T
    D_mats = get_D_constraint_mats(problem, rank)
    D_to_sum = [
        b[problem.instance_to_index[instance]] * D_mats[instance]
        for instance in problem.instances
    ]
    D_sum = cp.sum(D_to_sum, axis=0)
    obj_mat = problem.len * delta / num_pairs
    obj_mat = np.kron(obj_mat, np.eye(rank))
    obj_mat = np.kron(obj_mat, obj_mat)
    M = (
        D_sum
        + delta_sum
         - obj_mat
    )
    M = lam * np.eye(delta_sum.shape[0]) + M
    vec_M = cp.vec(M)
    pt_mat = partial_transpose_fast(M.shape[0])
    proj = symmetry_projection(M.shape[0])
    constraints = [
        cp.multiply(A, type_mask(problem)) == A,
        proj @ M @ proj == M,
        M >> 0,
    ]
    opt_prob = cp.Problem(cp.Minimize(lam), constraints)
    opt_prob.solve(solver="MOSEK", verbose=True)
    print(M.value)
    print("obj", opt_prob.value)
    return A.value, b.value, M.value, constraints

# %%
n = 3
prob = threshold_k(n, 1)

# %%
rank = 1
A, b, M, constraints = space_adv_psd(prob, rank)
for c in constraints:
    print(c.dual_value)
# Out:
# 1.268383339647875
# 1.268383339647875
# 1.268383339647875
# /home/bholman/anaconda3/envs/convex/lib/python3.13/site-packages/cvxpy/atoms/affine/vec.py:40: FutureWarning:
#     You didn't specify the order of the vec expression. The default order
#     used in CVXPY is Fortran ('F') order. This default will change to match NumPy's
#     default order ('C') in a future version of CVXPY.
#     To suppress this warning, please specify the order explicitly.
#
#   warnings.warn(vec_order_warning, FutureWarning)
# (CVXPY) Aug 19 02:28:17 PM: Your problem has 21 variables, 41488 constraints, and 0 parameters.
# (CVXPY) Aug 19 02:28:17 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Aug 19 02:28:17 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Aug 19 02:28:17 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Aug 19 02:28:17 PM: Your problem is compiled with the CPP canonicalization backend.
# (CVXPY) Aug 19 02:28:17 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Aug 19 02:28:17 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Aug 19 02:28:17 PM: Applying reduction Dcp2Cone
# (CVXPY) Aug 19 02:28:17 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Aug 19 02:28:17 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Aug 19 02:28:17 PM: Applying reduction MOSEK
# (CVXPY) Aug 19 02:28:17 PM: Finished problem compilation (took 2.866e-02 seconds).
# (CVXPY) Aug 19 02:28:17 PM: Invoking solver MOSEK  to obtain a solution.
# (CVXPY) Aug 19 02:28:17 PM: Problem
# (CVXPY) Aug 19 02:28:17 PM:   Name                   :
# (CVXPY) Aug 19 02:28:17 PM:   Objective sense        : maximize
# (CVXPY) Aug 19 02:28:17 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Aug 19 02:28:17 PM:   Constraints            : 15
# (CVXPY) Aug 19 02:28:17 PM:   Affine conic cons.     : 0
# (CVXPY) Aug 19 02:28:17 PM:   Disjunctive cons.      : 0
# (CVXPY) Aug 19 02:28:17 PM:   Cones                  : 0
# (CVXPY) Aug 19 02:28:17 PM:   Scalar variables       : 20752
# (CVXPY) Aug 19 02:28:17 PM:   Matrix variables       : 1 (scalarized: 10440)
# (CVXPY) Aug 19 02:28:17 PM:   Integer variables      : 0
# (CVXPY) Aug 19 02:28:17 PM:
# (CVXPY) Aug 19 02:28:17 PM: Optimizer started.
# (CVXPY) Aug 19 02:28:17 PM: Presolve started.
# (CVXPY) Aug 19 02:28:17 PM: Linear dependency checker started.
# (CVXPY) Aug 19 02:28:17 PM: Linear dependency checker terminated.
# (CVXPY) Aug 19 02:28:17 PM: Eliminator started.
# (CVXPY) Aug 19 02:28:17 PM: Freed constraints in eliminator : 0
# (CVXPY) Aug 19 02:28:17 PM: Eliminator terminated.
# (CVXPY) Aug 19 02:28:17 PM: Eliminator started.
# (CVXPY) Aug 19 02:28:17 PM: Freed constraints in eliminator : 0
# (CVXPY) Aug 19 02:28:17 PM: Eliminator terminated.
# (CVXPY) Aug 19 02:28:17 PM: Eliminator - tries                  : 2                 time                   : 0.00
# (CVXPY) Aug 19 02:28:17 PM: Lin. dep.  - tries                  : 1                 time                   : 0.00
# (CVXPY) Aug 19 02:28:17 PM: Lin. dep.  - primal attempts        : 1                 successes              : 1
# (CVXPY) Aug 19 02:28:17 PM: Lin. dep.  - dual attempts          : 0                 successes              : 0
# (CVXPY) Aug 19 02:28:17 PM: Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# (CVXPY) Aug 19 02:28:17 PM: Presolve terminated. Time: 0.00
# (CVXPY) Aug 19 02:28:17 PM: Optimizer  - threads                : 16
# (CVXPY) Aug 19 02:28:17 PM: Optimizer  - solved problem         : the primal
# (CVXPY) Aug 19 02:28:17 PM: Optimizer  - Constraints            : 8
# (CVXPY) Aug 19 02:28:17 PM: Optimizer  - Cones                  : 1
# (CVXPY) Aug 19 02:28:17 PM: Optimizer  - Scalar variables       : 17                conic                  : 17
# (CVXPY) Aug 19 02:28:17 PM: Optimizer  - Semi-definite variables: 1                 scalarized             : 10440
# (CVXPY) Aug 19 02:28:17 PM: Factor     - setup time             : 0.00
# (CVXPY) Aug 19 02:28:17 PM: Factor     - dense det. time        : 0.00              GP order time          : 0.00
# (CVXPY) Aug 19 02:28:17 PM: Factor     - nonzeros before factor : 36                after factor           : 36
# (CVXPY) Aug 19 02:28:17 PM: Factor     - dense dim.             : 0                 flops                  : 4.92e+05
# (CVXPY) Aug 19 02:28:17 PM: ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# (CVXPY) Aug 19 02:28:17 PM: 0   1.4e+02  1.0e+00  1.0e+00  0.00e+00   -0.000000000e+00  -0.000000000e+00  1.0e+00  0.01
# (CVXPY) Aug 19 02:28:17 PM: 1   9.2e+01  6.4e-01  6.6e-01  -5.72e-01  6.398331376e-01   4.311108035e-01   6.4e-01  0.02
# (CVXPY) Aug 19 02:28:17 PM: 2   8.2e+01  5.7e-01  1.3e+00  -1.79e+00  3.086794596e+00   -5.578369446e-02  5.7e-01  0.03
# (CVXPY) Aug 19 02:28:17 PM: 3   1.2e+01  8.3e-02  3.8e-01  -1.82e+00  2.010798204e+01   3.438470910e-01   8.3e-02  0.04
# (CVXPY) Aug 19 02:28:17 PM: 4   5.5e-02  3.8e-04  2.8e-02  -1.07e+00  5.264512998e+03   -2.499390606e-01  3.8e-04  0.05
# (CVXPY) Aug 19 02:28:17 PM: 5   1.0e-08  7.2e-11  1.3e-05  -1.00e+00  3.239580862e+10   -1.477194764e-01  7.2e-11  0.06
# (CVXPY) Aug 19 02:28:17 PM: 6   1.4e-14  4.5e-21  1.6e-10  -1.00e+00  1.893617885e+00   2.992844469e-21   4.5e-21  0.06
# (CVXPY) Aug 19 02:28:17 PM: Optimizer terminated. Time: 0.07
# (CVXPY) Aug 19 02:28:17 PM:
# (CVXPY) Aug 19 02:28:17 PM:
# (CVXPY) Aug 19 02:28:17 PM: Interior-point solution summary
# (CVXPY) Aug 19 02:28:17 PM:   Problem status  : DUAL_INFEASIBLE
# (CVXPY) Aug 19 02:28:17 PM:   Solution status : DUAL_INFEASIBLE_CER
# (CVXPY) Aug 19 02:28:17 PM:   Primal.  obj: 1.8936178854e+00    nrm: 2e+01    Viol.  con: 1e-14    var: 0e+00    barvar: 0e+00
# (CVXPY) Aug 19 02:28:17 PM: Problem status: infeasible
# (CVXPY) Aug 19 02:28:17 PM: Optimal value: inf
# (CVXPY) Aug 19 02:28:17 PM: Compilation took 2.866e-02 seconds
# (CVXPY) Aug 19 02:28:17 PM: Solver (including time spent in interface) took 7.509e-02 seconds
# size 144
# small size 12
# <COOrdinate sparse array of dtype 'float64'
# 	with 12 stored elements and shape (12, 12)>
#   Coords	Values
#   (0, 0)	1.0
#   (1, 1)	1.0
#   (2, 2)	1.0
#   (3, 3)	1.0
#   (4, 4)	1.0
#   (5, 5)	1.0
#   (6, 6)	1.0
#   (7, 7)	1.0
#   (8, 8)	1.0
#   (9, 9)	1.0
#   (10, 10)	1.0
#   (11, 11)	1.0
# (20736, 20736) (144, 144)
# ===============================================================================
#                                      CVXPY
#                                      v1.6.6
# ===============================================================================
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# None
# obj inf
# None
# None
# None

# %%
def span_program_sep_psd(problem, rank):
    num_pairs = 2 * problem.no_len * problem.yes_len
    delta, labels = get_delta(problem)
    deltas = get_delta_constraint_mats(problem, rank)
    n = problem.n
    D_mats = get_D_constraint_mats(problem, rank)
    X_len = problem.len * n * rank
    X_len = X_len**2
    X = cp.Variable((X_len, X_len), PSD=True)
    proj = symmetry_projection(X.shape[0])
    constraints = [
        cp.trace(X) == 1,
        partial_transpose_fast(X.shape[0]) @ cp.vec(X, order="F") == cp.vec(X),
        proj @ X @ proj == X,
    ]

    constraints += [
        cp.trace(M @ X) == 0 for M in list(deltas.values()) + list(D_mats.values())
    ]
    obj = (
        problem.len
        * cp.trace(np.kron(delta, np.eye(X.shape[0] // delta.shape[0])) @ X)
        / num_pairs
    )
    opt_prob = cp.Problem(cp.Maximize(obj), constraints)
    opt_prob.solve(solver="MOSEK", verbose=True)
    print("obj", opt_prob.value)
    return X.value

# %% [raw]
# def avg_adv_bound(problem):
#     deltas = get_deltas(problem)
#     Ds = get_Ds(problem)
#     A = cp.Variable((problem.len, problem.len), symmetric=True)
#     b = cp.Variable(problem.len)
#     num_pairs = problem.no_len * problem.yes_len
#     delta = get_delta(problem) / num_pairs
#     constraints = [
#         delta -
#     ]

# %%
class AdvBound():
    def __init__(self, problem, normalize=False, single_variable=False):
        self.problem = problem
        self.single_variable = single_variable
        self.normalize = normalize
        # Problem short-hand
        self.n = self.problem.n
        self.to_index = self.problem.instance_to_index
        
        # variables
        self.constraints = []
        self.constraint_mats = []

        self.set_variables()
        self.set_constraints()
        self.set_opt_prob()
        
    def set_variables(self):
        self.A = cp.Variable((self.problem.len, self.problem.len), symmetric=True)
        self.diag_weights = cp.Variable(self.problem.len)
    
    # constraint matrices
    def set_constraints(self):
        deltas = get_deltas(self.problem)
        Ds = get_Ds(self.problem)
        delta_combo = cp.sum([self.A[self.to_index[no], self.to_index[yes]] * delta for (no, yes), delta in deltas.items()], axis=0)
        delta_combo = delta_combo + delta_combo.T 
        D_combo = cp.sum([self.diag_weights[i] * Ds[i] for i in range(self.problem.len)], axis=0)
        self.constraints += [
            cp.sum(self.diag_weights) == 1,
            D_combo >> delta_combo
        
        ]
        self.constraint_mats += [delta_combo, D_combo]
            
    def set_opt_prob(self):     
        self.opt_prob = cp.Problem(cp.Maximize(cp.sum(cp.multiply(self.A, type_mask(self.problem)))), constraints=self.constraints)       
    
    def solve(self):
        self.opt_prob.solve("MOSEK", verbose=True)

# %%
adv = AdvBound(prob)
adv.solve()
visualize(adv.A.value)
# Out:
# (CVXPY) Aug 19 01:31:50 PM: Your problem has 20 variables, 145 constraints, and 0 parameters.
# (CVXPY) Aug 19 01:31:50 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Aug 19 01:31:50 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Aug 19 01:31:50 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Aug 19 01:31:50 PM: Your problem is compiled with the CPP canonicalization backend.
# (CVXPY) Aug 19 01:31:50 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Aug 19 01:31:50 PM: Reduction chain: FlipObjective -> Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Aug 19 01:31:50 PM: Applying reduction FlipObjective
# (CVXPY) Aug 19 01:31:50 PM: Applying reduction Dcp2Cone
# (CVXPY) Aug 19 01:31:50 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Aug 19 01:31:50 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Aug 19 01:31:50 PM: Applying reduction MOSEK
# (CVXPY) Aug 19 01:31:50 PM: Finished problem compilation (took 7.593e-03 seconds).
# (CVXPY) Aug 19 01:31:50 PM: Invoking solver MOSEK  to obtain a solution.
# (CVXPY) Aug 19 01:31:50 PM: Problem
# (CVXPY) Aug 19 01:31:50 PM:   Name                   :
# (CVXPY) Aug 19 01:31:50 PM:   Objective sense        : maximize
# (CVXPY) Aug 19 01:31:50 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Aug 19 01:31:50 PM:   Constraints            : 14
# (CVXPY) Aug 19 01:31:50 PM:   Affine conic cons.     : 0
# (CVXPY) Aug 19 01:31:50 PM:   Disjunctive cons.      : 0
# (CVXPY) Aug 19 01:31:50 PM:   Cones                  : 0
# (CVXPY) Aug 19 01:31:50 PM:   Scalar variables       : 1
# (CVXPY) Aug 19 01:31:50 PM:   Matrix variables       : 1 (scalarized: 78)
# (CVXPY) Aug 19 01:31:50 PM:   Integer variables      : 0
# (CVXPY) Aug 19 01:31:50 PM:
# (CVXPY) Aug 19 01:31:50 PM: Optimizer started.
# (CVXPY) Aug 19 01:31:50 PM: Presolve started.
# (CVXPY) Aug 19 01:31:50 PM: Linear dependency checker started.
# (CVXPY) Aug 19 01:31:50 PM: Linear dependency checker terminated.
# (CVXPY) Aug 19 01:31:50 PM: Eliminator started.
# (CVXPY) Aug 19 01:31:50 PM: Freed constraints in eliminator : 0
# (CVXPY) Aug 19 01:31:50 PM: Eliminator terminated.
# (CVXPY) Aug 19 01:31:50 PM: Eliminator - tries                  : 1                 time                   : 0.00
# (CVXPY) Aug 19 01:31:50 PM: Lin. dep.  - tries                  : 1                 time                   : 0.00
# (CVXPY) Aug 19 01:31:50 PM: Lin. dep.  - primal attempts        : 1                 successes              : 1
# (CVXPY) Aug 19 01:31:50 PM: Lin. dep.  - dual attempts          : 0                 successes              : 0
# (CVXPY) Aug 19 01:31:50 PM: Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# (CVXPY) Aug 19 01:31:50 PM: Presolve terminated. Time: 0.00
# (CVXPY) Aug 19 01:31:50 PM: Optimizer  - threads                : 16
# (CVXPY) Aug 19 01:31:50 PM: Optimizer  - solved problem         : the primal
# (CVXPY) Aug 19 01:31:50 PM: Optimizer  - Constraints            : 7
# (CVXPY) Aug 19 01:31:50 PM: Optimizer  - Cones                  : 1
# (CVXPY) Aug 19 01:31:50 PM: Optimizer  - Scalar variables       : 2                 conic                  : 2
# (CVXPY) Aug 19 01:31:50 PM: Optimizer  - Semi-definite variables: 1                 scalarized             : 78
# (CVXPY) Aug 19 01:31:50 PM: Factor     - setup time             : 0.00
# (CVXPY) Aug 19 01:31:50 PM: Factor     - dense det. time        : 0.00              GP order time          : 0.00
# (CVXPY) Aug 19 01:31:50 PM: Factor     - nonzeros before factor : 28                after factor           : 28
# (CVXPY) Aug 19 01:31:50 PM: Factor     - dense dim.             : 0                 flops                  : 1.00e+03
# (CVXPY) Aug 19 01:31:50 PM: ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# (CVXPY) Aug 19 01:31:50 PM: 0   3.0e+00  1.0e+00  1.0e+00  0.00e+00   -0.000000000e+00  -0.000000000e+00  1.0e+00  0.00
# (CVXPY) Aug 19 01:31:50 PM: 1   6.9e-01  2.3e-01  1.0e-01  8.54e-01   -1.333574039e+00  -1.300839029e+00  2.3e-01  0.00
# (CVXPY) Aug 19 01:31:50 PM: 2   1.2e-01  4.1e-02  8.2e-03  1.99e+00   -8.740933722e-01  -8.872434087e-01  4.1e-02  0.00
# (CVXPY) Aug 19 01:31:50 PM: 3   1.5e-02  4.9e-03  3.3e-04  1.07e+00   -8.699334466e-01  -8.711642929e-01  4.9e-03  0.00
# (CVXPY) Aug 19 01:31:50 PM: 4   1.2e-04  4.0e-05  2.2e-07  1.01e+00   -8.660721135e-01  -8.660781357e-01  4.0e-05  0.00
# (CVXPY) Aug 19 01:31:50 PM: 5   7.7e-06  2.6e-06  3.7e-09  1.00e+00   -8.660258174e-01  -8.660262048e-01  2.6e-06  0.00
# (CVXPY) Aug 19 01:31:50 PM: 6   1.0e-06  3.5e-07  1.8e-10  1.00e+00   -8.660252374e-01  -8.660252836e-01  3.5e-07  0.01
# (CVXPY) Aug 19 01:31:50 PM: 7   5.1e-08  1.7e-08  1.9e-12  1.00e+00   -8.660253931e-01  -8.660253948e-01  1.7e-08  0.01
# (CVXPY) Aug 19 01:31:50 PM: 8   7.3e-10  3.4e-10  3.3e-15  1.00e+00   -8.660254036e-01  -8.660254036e-01  2.4e-10  0.01
# (CVXPY) Aug 19 01:31:50 PM: Optimizer terminated. Time: 0.01
# (CVXPY) Aug 19 01:31:50 PM:
# (CVXPY) Aug 19 01:31:50 PM:
# (CVXPY) Aug 19 01:31:50 PM: Interior-point solution summary
# (CVXPY) Aug 19 01:31:50 PM:   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
# (CVXPY) Aug 19 01:31:50 PM:   Solution status : OPTIMAL
# (CVXPY) Aug 19 01:31:50 PM:   Primal.  obj: -8.6602540361e-01   nrm: 2e+00    Viol.  con: 5e-10    var: 0e+00    barvar: 1e+00
# (CVXPY) Aug 19 01:31:50 PM:   Dual.    obj: -8.6602540363e-01   nrm: 5e-01    Viol.  con: 0e+00    var: 9e-11    barvar: 1e+00
# (CVXPY) Aug 19 01:31:50 PM: Problem status: optimal
# (CVXPY) Aug 19 01:31:50 PM: Optimal value: 8.660e-01
# (CVXPY) Aug 19 01:31:50 PM: Compilation took 7.593e-03 seconds
# (CVXPY) Aug 19 01:31:50 PM: Solver (including time spent in interface) took 8.806e-03 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.6.6
# ===============================================================================
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------

# %%
def span_bound(problem, single_variable=False, normalize=False):
    n = problem.n
    to_index = problem.instance_to_index

    var_size = problem.len * n
    X = cp.Variable((var_size, var_size), PSD=True)
    t = cp.Variable(nonneg=True)

    deltas = get_deltas(problem)
    Ds = get_Ds(problem)
    D_avg = np.sum(Ds, axis=0) / len(Ds)
    delta_avg = np.sum(list(deltas.values()), axis=0) / len(deltas)
    delta_eq = cp.trace(delta_avg@X) if normalize else 1
    constraints = []
    
    if normalize:
        # Ds = [D - D_avg for D in Ds]
        constraints += [cp.trace((D-np.eye(var_size)/problem.len)@X) == 0 for D in Ds]
        constraints += [cp.trace(X) == 1]
        obj = problem.len * cp.trace(delta_avg@X)
    else:
        constraints += [cp.trace(D@X) == t for D in Ds]
        obj = t
    constraints += [cp.trace(delta@X) == delta_eq for delta in deltas.values()]

    opt_prob = cp.Problem(cp.Maximize(obj) if normalize else cp.Minimize(obj), constraints=constraints)
    opt_prob.solve("MOSEK", verbose=True)

    return X.value, opt_prob.value

# %%
X, t = span_bound(prob, single_variable=True, normalize=True)
print(1/t)
visualize(X)
# Out:
# (CVXPY) Aug 19 02:03:57 PM: Your problem has 144 variables, 8 constraints, and 0 parameters.
# (CVXPY) Aug 19 02:03:57 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Aug 19 02:03:57 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Aug 19 02:03:57 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Aug 19 02:03:57 PM: Your problem is compiled with the CPP canonicalization backend.
# (CVXPY) Aug 19 02:03:57 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Aug 19 02:03:57 PM: Reduction chain: FlipObjective -> Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Aug 19 02:03:57 PM: Applying reduction FlipObjective
# (CVXPY) Aug 19 02:03:57 PM: Applying reduction Dcp2Cone
# (CVXPY) Aug 19 02:03:57 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Aug 19 02:03:57 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Aug 19 02:03:57 PM: Applying reduction MOSEK
# (CVXPY) Aug 19 02:03:57 PM: Finished problem compilation (took 1.128e-02 seconds).
# (CVXPY) Aug 19 02:03:57 PM: Invoking solver MOSEK  to obtain a solution.
# (CVXPY) Aug 19 02:03:57 PM: Problem
# (CVXPY) Aug 19 02:03:57 PM:   Name                   :
# (CVXPY) Aug 19 02:03:57 PM:   Objective sense        : maximize
# (CVXPY) Aug 19 02:03:57 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Aug 19 02:03:57 PM:   Constraints            : 78
# (CVXPY) Aug 19 02:03:57 PM:   Affine conic cons.     : 0
# (CVXPY) Aug 19 02:03:57 PM:   Disjunctive cons.      : 0
# (CVXPY) Aug 19 02:03:57 PM:   Cones                  : 0
# (CVXPY) Aug 19 02:03:57 PM:   Scalar variables       : 8
# (CVXPY) Aug 19 02:03:57 PM:   Matrix variables       : 1 (scalarized: 78)
# (CVXPY) Aug 19 02:03:57 PM:   Integer variables      : 0
# (CVXPY) Aug 19 02:03:57 PM:
# (CVXPY) Aug 19 02:03:57 PM: Optimizer started.
# (CVXPY) Aug 19 02:03:57 PM: Presolve started.
# (CVXPY) Aug 19 02:03:57 PM: Linear dependency checker started.
# (CVXPY) Aug 19 02:03:57 PM: Linear dependency checker terminated.
# (CVXPY) Aug 19 02:03:57 PM: Eliminator started.
# (CVXPY) Aug 19 02:03:57 PM: Freed constraints in eliminator : 0
# (CVXPY) Aug 19 02:03:57 PM: Eliminator terminated.
# (CVXPY) Aug 19 02:03:57 PM: Eliminator - tries                  : 1                 time                   : 0.00
# (CVXPY) Aug 19 02:03:57 PM: Lin. dep.  - tries                  : 1                 time                   : 0.00
# (CVXPY) Aug 19 02:03:57 PM: Lin. dep.  - primal attempts        : 1                 successes              : 1
# (CVXPY) Aug 19 02:03:57 PM: Lin. dep.  - dual attempts          : 0                 successes              : 0
# (CVXPY) Aug 19 02:03:57 PM: Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# (CVXPY) Aug 19 02:03:57 PM: Presolve terminated. Time: 0.00
# (CVXPY) Aug 19 02:03:57 PM: Optimizer  - threads                : 16
# (CVXPY) Aug 19 02:03:57 PM: Optimizer  - solved problem         : the primal
# (CVXPY) Aug 19 02:03:57 PM: Optimizer  - Constraints            : 78
# (CVXPY) Aug 19 02:03:57 PM: Optimizer  - Cones                  : 1
# (CVXPY) Aug 19 02:03:57 PM: Optimizer  - Scalar variables       : 9                 conic                  : 9
# (CVXPY) Aug 19 02:03:57 PM: Optimizer  - Semi-definite variables: 1                 scalarized             : 78
# (CVXPY) Aug 19 02:03:57 PM: Factor     - setup time             : 0.00
# (CVXPY) Aug 19 02:03:57 PM: Factor     - dense det. time        : 0.00              GP order time          : 0.00
# (CVXPY) Aug 19 02:03:57 PM: Factor     - nonzeros before factor : 3081              after factor           : 3081
# (CVXPY) Aug 19 02:03:57 PM: Factor     - dense dim.             : 0                 flops                  : 1.85e+05
# (CVXPY) Aug 19 02:03:57 PM: ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# (CVXPY) Aug 19 02:03:57 PM: 0   1.3e+00  1.0e+00  1.0e+00  0.00e+00   -0.000000000e+00  -0.000000000e+00  1.0e+00  0.00
# (CVXPY) Aug 19 02:03:57 PM: 1   1.8e-01  1.3e-01  1.6e-01  -6.72e-01  -2.009821362e+00  -3.172061552e+00  1.3e-01  0.00
# (CVXPY) Aug 19 02:03:57 PM: 2   3.5e-02  2.7e-02  1.0e-02  1.87e+00   -1.197080318e+00  -1.301495907e+00  2.7e-02  0.00
# (CVXPY) Aug 19 02:03:57 PM: 3   6.4e-03  4.8e-03  7.2e-04  1.17e+00   -1.150752150e+00  -1.167185791e+00  4.8e-03  0.00
# (CVXPY) Aug 19 02:03:57 PM: 4   1.7e-04  1.3e-04  3.2e-06  1.00e+00   -1.155461345e+00  -1.155884111e+00  1.3e-04  0.01
# (CVXPY) Aug 19 02:03:57 PM: 5   7.1e-06  5.3e-06  2.5e-08  1.00e+00   -1.154753195e+00  -1.154767003e+00  5.3e-06  0.01
# (CVXPY) Aug 19 02:03:57 PM: 6   4.2e-08  3.1e-08  1.1e-11  1.00e+00   -1.154700894e+00  -1.154700973e+00  3.1e-08  0.01
# (CVXPY) Aug 19 02:03:57 PM: 7   2.7e-11  2.1e-11  1.8e-16  1.00e+00   -1.154700539e+00  -1.154700539e+00  2.0e-11  0.01
# (CVXPY) Aug 19 02:03:57 PM: Optimizer terminated. Time: 0.01
# (CVXPY) Aug 19 02:03:57 PM:
# (CVXPY) Aug 19 02:03:57 PM:
# (CVXPY) Aug 19 02:03:57 PM: Interior-point solution summary
# (CVXPY) Aug 19 02:03:57 PM:   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
# (CVXPY) Aug 19 02:03:57 PM:   Solution status : OPTIMAL
# (CVXPY) Aug 19 02:03:57 PM:   Primal.  obj: -1.1547005386e+00   nrm: 3e+00    Viol.  con: 7e-11    var: 0e+00    barvar: 1e+00
# (CVXPY) Aug 19 02:03:57 PM:   Dual.    obj: -1.1547005387e+00   nrm: 3e-01    Viol.  con: 0e+00    var: 2e-11    barvar: 1e+00
# (CVXPY) Aug 19 02:03:57 PM: Problem status: optimal
# (CVXPY) Aug 19 02:03:57 PM: Optimal value: 1.155e+00
# (CVXPY) Aug 19 02:03:57 PM: Compilation took 1.128e-02 seconds
# (CVXPY) Aug 19 02:03:57 PM: Solver (including time spent in interface) took 9.896e-03 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.6.6
# ===============================================================================
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# 0.866025403567752
